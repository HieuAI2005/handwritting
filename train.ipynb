# %%
# from glob import glob
# from PIL import Image
# import torchvision.transforms as T
# import torch
# from tqdm import tqdm

# image_paths = glob("/home/hiwe/project/deeplearning/project/handwriting/data/train/*.jpg")
# transform = T.ToTensor()

# mean = 0.
# std = 0.
# nb_samples = 0

# for path in tqdm(image_paths):
#     img = Image.open(path).convert("RGB")
#     tensor = transform(img)
#     nb_samples += 1
#     mean += tensor.mean(dim=(1, 2))
#     std += tensor.std(dim=(1, 2))

# mean /= nb_samples
# std /= nb_samples

# print(f"Mean: {mean}, Std: {std}")

# %%
from torch.utils.data import Dataset
from PIL import Image
import pandas as pd
import os
import torch

class OCRDataset(Dataset):
    def __init__(self, img_dir, label_csv, transform=None):
        self.img_dir = img_dir
        self.transform = transform
        self.samples = pd.read_csv(label_csv)
        self.samples.columns = ['FILENAME', 'IDENTITY']
        
        self.samples = self.samples.dropna(subset=['IDENTITY'])
        self.samples['IDENTITY'] = self.samples['IDENTITY'].astype(str)
        all_text = ''.join(self.samples['IDENTITY'].tolist())
        unique_chars = sorted(set(all_text))
        
        self.blank_token = '<blank>'
        self.char2idx = {self.blank_token: 0}
        for idx, char in enumerate(unique_chars, start=1):
            self.char2idx[char] = idx

        self.idx2char = {v: k for k, v in self.char2idx.items()}
        self.blank_idx = self.char2idx[self.blank_token]

    def __len__(self):
        return len(self.samples)

    def __getitem__(self, idx):
        row = self.samples.iloc[idx]
        img_path = os.path.join(self.img_dir, row['FILENAME'])
        label_text = row['IDENTITY']

        image = Image.open(img_path).convert("L")
        if self.transform:
            image = self.transform(image)

        label_encoded = [self.char2idx[c] for c in label_text]
        label_tensor = torch.tensor(label_encoded, dtype=torch.long)
        label_length = len(label_encoded)
        
        return image, label_tensor, label_length

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader 
from torchvision.transforms import transforms
from model import BasicModel

# === Data transforms ===
train_transform = transforms.Compose([
    transforms.Resize((32, 256)),
    transforms.RandomAffine(degrees=5, translate=(0.05, 0.05), scale=(0.95, 1.05)),
    transforms.ColorJitter(brightness=0.2, contrast=0.2),
    transforms.ToTensor(),
    transforms.Normalize((0.5, ), (0.5, ))
])

val_transform = transforms.Compose([
    transforms.Resize((32, 256)),
    transforms.ToTensor(),
    transforms.Normalize((0.5, ), (0.5, ))
])

# === Datasets ===
train_dataset = OCRDataset(
    img_dir='data/train',
    label_csv='train_labels.csv',
    transform=train_transform
)
val_dataset = OCRDataset(
    img_dir='data/validation',
    label_csv='val_labels.csv',
    transform=val_transform
)
test_dataset = OCRDataset(
    img_dir='data/test',
    label_csv='test_labels.csv',
    transform=val_transform
)

# === char2idx & blank ===
char2idx = train_dataset.char2idx
idx2char = {v: k for k, v in char2idx.items()}
blank_idx = char2idx['<blank>']

# === Decoder ===
def greedy_decoder(output, blank=0):
    output = output.permute(1, 0, 2)  # (T, N, C) → (N, T, C)
    decoded = []
    for probs in output:
        pred = torch.argmax(probs, dim=1)
        prev = -1
        new_seq = []
        for p in pred:
            p = p.item()
            if p != prev and p != blank:
                new_seq.append(p)
            prev = p
        decoded.append(new_seq)
    return decoded

# === Accuracy ===
def compute_accuracy(preds, targets, target_lengths):
    acc = 0
    total = len(target_lengths)
    split_targets = torch.split(targets, target_lengths.tolist())
    for pred, target in zip(preds, split_targets):
        if pred == target.tolist():
            acc += 1
    return acc / total

# === Collate function ===
def ocr_collate_fn(batch):
    images, labels, lengths = zip(*batch)
    images = torch.stack(images, 0)
    labels = torch.cat(labels)
    lengths = torch.tensor(lengths, dtype=torch.long)
    return images, labels, lengths

# === DataLoader ===
train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True, collate_fn=ocr_collate_fn)
val_loader = DataLoader(val_dataset, batch_size=32, shuffle=False, collate_fn=ocr_collate_fn)
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False, collate_fn=ocr_collate_fn)

# === Model ===
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = BasicModel(num_classes=len(char2idx)).to(device)
criterion = nn.CTCLoss(blank=blank_idx, zero_infinity=True)
optimizer = optim.Adam(model.parameters(), lr=1e-3, weight_decay=1e-5)

# === Training ===
num_epochs = 200
train_accuracy = []
train_losses = []
val_accuracy = []
val_losses = []
best = 0.0 
print("Start Training")

for epoch in range(num_epochs):
    model.train()
    train_loss = 0.0
    correct, total = 0, 0

    for x, y, target_lengths in train_loader:
        x, y, target_lengths = x.to(device), y.to(device), target_lengths.to(device)
        optimizer.zero_grad()
        outputs = model(x)  # (T, N, C)

        input_lengths = torch.full(size=(outputs.size(1),), fill_value=outputs.size(0), dtype=torch.long).to(device)
        loss = criterion(outputs, y, input_lengths, target_lengths)
        loss.backward()
        optimizer.step()
        train_loss += loss.item()

        decoded_preds = greedy_decoder(outputs.detach().cpu(), blank=blank_idx)
        split_targets = torch.split(y.cpu(), target_lengths.cpu().tolist())

        for pred, target in zip(decoded_preds, split_targets):
            if pred == target.tolist():
                correct += 1
            total += 1

    acc_train = 100.0 * correct / total
    avg_train_loss = train_loss / len(train_loader)
    train_losses.append(avg_train_loss)
    train_accuracy.append(acc_train)

    # === Print sample decode ===
    print(f"\n[Epoch {epoch}]")
    for i in range(min(3, len(decoded_preds))):
        pred_str = ''.join([idx2char[c] for c in decoded_preds[i]])
        true_str = ''.join([idx2char[c.item()] for c in split_targets[i]])
        print(f"Pred: {pred_str} | True: {true_str}")

    # === Validation ===
    model.eval()
    val_loss = 0.0
    correct, total = 0, 0
    with torch.no_grad():
        for x, y, target_lengths in val_loader:
            x, y, target_lengths = x.to(device), y.to(device), target_lengths.to(device)
            outputs = model(x)
            input_lengths = torch.full(size=(outputs.size(1),), fill_value=outputs.size(0), dtype=torch.long).to(device)
            loss = criterion(outputs, y, input_lengths, target_lengths)
            val_loss += loss.item()

            decoded_preds = greedy_decoder(outputs.cpu(), blank=blank_idx)
            split_targets = torch.split(y.cpu(), target_lengths.cpu().tolist())

            for pred, target in zip(decoded_preds, split_targets):
                if pred == target.tolist():
                    correct += 1
                total += 1

    val_acc = 100.0 * correct / total
    avg_val_loss = val_loss / len(val_loader)
    val_accuracy.append(val_acc)
    val_losses.append(avg_val_loss)

    print(f"Train Loss: {avg_train_loss:.4f}, Train Acc: {acc_train:.2f}%, Val Loss: {avg_val_loss:.4f}, Val Acc: {val_acc:.2f}%")

    if val_acc > best:
        best = val_acc 
        torch.save(model.state_dict(), 'model_best.pth')
        print(f'Saving the model with {val_acc:.2f}')
        

torch.save(model.state_dict(), 'model_last.pth')
print(f'Saving the last model with {val_acc:.2f}')
# === Test ===
model.eval()
correct = 0
total = 0

with torch.no_grad():
    for images, labels, lengths in test_loader:
        images = images.to(device)
        labels = labels.to(device)
        lengths = lengths.to(device)

        logits = model(images)
        decoded_preds = greedy_decoder(logits.cpu(), blank=blank_idx)

        acc = compute_accuracy(decoded_preds, labels.cpu(), lengths.cpu())
        correct += acc * len(lengths)
        total += len(lengths)

test_accuracy = correct / total
print(f"\nFinal Test Accuracy: {test_accuracy:.3f}")
# Out:
# Start Training
#
# [Epoch 0]
# Pred:  | True: YSEE
# Pred:  | True: TIAGO
# Pred:  | True: EVAN
# Train Loss: 3.8387, Train Acc: 0.00%, Val Loss: 3.1683, Val Acc: 0.00%
#
# [Epoch 1]
# Pred:  | True: JACINTO
# Pred:  | True: WADSWORRE
# Pred:  | True: OVIZE
# Train Loss: 3.1546, Train Acc: 0.00%, Val Loss: 3.1417, Val Acc: 0.00%
#
# [Epoch 2]
# Pred:  | True: DADDE
# Pred:  | True: ERWAN
# Pred:  | True: MILENA
# Train Loss: 3.1333, Train Acc: 0.00%, Val Loss: 3.1167, Val Acc: 0.00%
#
# [Epoch 3]
# Pred:  | True: CHOQUET
# Pred:  | True: PINON
# Pred:  | True: OUDOTDEDAINVILLE
# Train Loss: 3.1178, Train Acc: 0.00%, Val Loss: 3.0965, Val Acc: 0.00%
#
# [Epoch 4]
# Pred:  | True: BRICEAU
# Pred:  | True: GAELLE
# Pred:  | True: FABIEN
# Train Loss: 3.1034, Train Acc: 0.00%, Val Loss: 3.0960, Val Acc: 0.00%
#
# [Epoch 5]
# Pred: M | True: TANAIS
# Pred: M | True: GENTEUIL
# Pred: L | True: ACELYA
# Train Loss: 3.0868, Train Acc: 0.00%, Val Loss: 3.0695, Val Acc: 0.00%
#
# [Epoch 6]
# Pred: L | True: QUENTIN
# Pred: BE | True: MARIAH
# Pred: A | True: ROY
# Train Loss: 3.0772, Train Acc: 0.00%, Val Loss: 3.0966, Val Acc: 0.00%
#
# [Epoch 7]
# Pred: A | True: HENRI
# Pred: A | True: CONDE-LAVALETTE
# Pred: MA | True: APER
# Train Loss: 3.0631, Train Acc: 0.00%, Val Loss: 3.0430, Val Acc: 0.00%
#
# [Epoch 8]
# Pred: AE | True: HARDY
# Pred: AE | True: MOURARD
# Pred: AE | True: MARION
# Train Loss: 3.0510, Train Acc: 0.00%, Val Loss: 3.0452, Val Acc: 0.00%
#
# [Epoch 9]
# Pred: A | True: ROBIN
# Pred: A | True: RESO
# Pred: AE | True: RETER
# Train Loss: 3.0454, Train Acc: 0.00%, Val Loss: 3.0505, Val Acc: 0.00%
#
# [Epoch 10]
# Pred: A | True: CLEMENCE
# Pred: E | True: DJAVID
# Pred: A | True: RASSENT
# Train Loss: 3.0455, Train Acc: 0.00%, Val Loss: 3.0274, Val Acc: 0.00%
#
# [Epoch 11]
# Pred: AE | True: RAYANE
# Pred: AE | True: ROOSE
# Pred: A | True: AWAYOGO
# Train Loss: 3.0419, Train Acc: 0.00%, Val Loss: 3.0293, Val Acc: 0.00%
#
# [Epoch 12]
# Pred: AE | True: PERDREAU
# Pred: A | True: SILVESTRI
# Pred: A | True: POISSON
# Train Loss: 3.0323, Train Acc: 0.00%, Val Loss: 3.0250, Val Acc: 0.00%
#
# [Epoch 13]
# Pred: A | True: DOREL
# Pred: A | True: AMADOU
# Pred: A | True: BLANCHETON
# Train Loss: 3.0322, Train Acc: 0.00%, Val Loss: 3.0076, Val Acc: 0.00%
#
# [Epoch 14]
# Pred: A | True: LEFEVRE
# Pred: A | True: ARTHUR
# Pred: A | True: SOFIA
# Train Loss: 3.0246, Train Acc: 0.00%, Val Loss: 3.0002, Val Acc: 0.00%
#
# [Epoch 15]
# Pred: AE | True: LOU-ANN
# Pred: A | True: CAGVIE
# Pred: A | True: LOUISA
# Train Loss: 3.0041, Train Acc: 0.00%, Val Loss: 2.9802, Val Acc: 0.00%
#
# [Epoch 16]
# Pred: AL | True: BECCHIO
# Pred: AE | True: PEDROSA
# Pred: A | True: MATTHIAS
# Train Loss: 2.9757, Train Acc: 0.00%, Val Loss: 2.9538, Val Acc: 0.00%
#
# [Epoch 17]
# Pred: ARN | True: GLANIOS
# Pred: CAUE | True: FROMENTIN
# Pred: AE | True: BRAJI
# Train Loss: 2.9578, Train Acc: 0.00%, Val Loss: 2.9475, Val Acc: 0.00%
#
# [Epoch 18]
# Pred: MARA | True: BERGEAULT
# Pred: AR | True: GRINAND
# Pred: ARE | True: REBELO
# Train Loss: 2.9458, Train Acc: 0.00%, Val Loss: 2.9495, Val Acc: 0.00%
#
# [Epoch 19]
# Pred: AE | True: KARROAM
# Pred: ANE | True: RAPHAEL
# Pred: AE | True: MALO
# Train Loss: 2.9350, Train Acc: 0.00%, Val Loss: 2.9008, Val Acc: 0.00%
#
# [Epoch 20]
# Pred: ANE | True: LE DEZ
# Pred: ARE | True: DEBERSE
# Pred: AE | True: LOLA
# Train Loss: 2.9247, Train Acc: 0.00%, Val Loss: 2.8891, Val Acc: 0.00%
#
# [Epoch 21]
# Pred: ARE | True: ZENOU
# Pred: ALEN | True: TI MOTHE
# Pred: BEREN | True: JUVIGNY FOURNIER
# Train Loss: 2.9126, Train Acc: 0.00%, Val Loss: 2.8667, Val Acc: 0.00%
#
# [Epoch 22]
# Pred: LALE | True: LUCIE
# Pred: ALN | True: ABDOU
# Pred: LARE | True: JEUDON
# Train Loss: 2.8952, Train Acc: 0.02%, Val Loss: 2.8549, Val Acc: 0.00%
#
# [Epoch 23]
# Pred: CARE | True: NAEPIS
# Pred: MARE | True: ACHOURI
# Pred: MARE | True: COURANT
# Train Loss: 2.8772, Train Acc: 0.00%, Val Loss: 2.8414, Val Acc: 0.00%
#
# [Epoch 24]
# Pred: ARE | True: TEDDY
# Pred: AUAN | True: NORAH
# Pred: ERIN | True: BELADGHAM
# Train Loss: 2.8514, Train Acc: 0.00%, Val Loss: 2.8614, Val Acc: 0.00%
#
# [Epoch 25]
# Pred: MAUE | True: MAYOT
# Pred: CEUINE | True: ELLEBOODE
# Pred: MARE | True: CHARLENE
# Train Loss: 2.7642, Train Acc: 0.04%, Val Loss: 2.6655, Val Acc: 0.30%
# Saving the model with 0.30
#
# [Epoch 26]
# Pred: BERNE | True: DENDANE
# Pred: CELEEAN | True: GROLLEAU
# Pred: O | True: EMMA
# Train Loss: 2.6586, Train Acc: 0.06%, Val Loss: 2.5182, Val Acc: 0.20%
#
# [Epoch 27]
# Pred: MAEL | True: ROGER
# Pred: EIN | True: PERRIER
# Pred: CASLN | True: LOUIS-LOUP
# Train Loss: 2.5093, Train Acc: 0.30%, Val Loss: 2.3231, Val Acc: 0.90%
# Saving the model with 0.90
#
# [Epoch 28]
# Pred: MALERTIELLLLAN | True: DEJESUSTEIXEIRA
# Pred: MILIOSE | True: ULYSSE
# Pred: GOORASE | True: SAUVAGE
# Train Loss: 2.2712, Train Acc: 0.66%, Val Loss: 1.9563, Val Acc: 1.90%
# Saving the model with 1.90
#
# [Epoch 29]
# Pred: MAULINE | True: MAYLINE
# Pred: MARIIN | True: MARTIN
# Pred: LOAIS | True: LOUIS
# Train Loss: 1.8722, Train Acc: 1.78%, Val Loss: 1.5063, Val Acc: 4.90%
# Saving the model with 4.90
#
# [Epoch 30]
# Pred: LOUANN | True: LOU-ANN
# Pred: AMUNIS | True: BAMONIO
# Pred: SACNS | True: BACHS
# Train Loss: 1.4735, Train Acc: 5.87%, Val Loss: 1.1987, Val Acc: 11.61%
# Saving the model with 11.61
#
# [Epoch 31]
# Pred: SIAD | True: SIAD
# Pred: MARIHUR | True: ARTHUR
# Pred: NOA | True: NOA
# Train Loss: 1.2683, Train Acc: 10.79%, Val Loss: 1.0718, Val Acc: 18.52%
# Saving the model with 18.52
#
# [Epoch 32]
# Pred: LOURIER | True: LOUZIER
# Pred: YOAA | True: YOAN
# Pred: TOUCET | True: YOUCEF
# Train Loss: 1.1084, Train Acc: 15.16%, Val Loss: 0.9216, Val Acc: 26.13%
# Saving the model with 26.13
#
# [Epoch 33]
# Pred: LUCAS | True: LUCAS
# Pred: AUREL | True: MOREL
# Pred: TIRAAE | True: PIERRE
# Train Loss: 0.9995, Train Acc: 19.26%, Val Loss: 0.8489, Val Acc: 29.63%
# Saving the model with 29.63
#
# [Epoch 34]
# Pred: PALANEHAND | True: PLANCHARD
# Pred: AUAOUR | True: DUHOUX
# Pred: MAIHIO | True: MATUFO
# Train Loss: 0.9077, Train Acc: 24.92%, Val Loss: 0.8073, Val Acc: 32.93%
# Saving the model with 32.93
#
# [Epoch 35]
# Pred: BERHILI | True: BERHILI
# Pred: CEZITRIII | True: COULIBALY
# Pred: LOU | True: LOU
# Train Loss: 0.8404, Train Acc: 28.85%, Val Loss: 0.7000, Val Acc: 40.54%
# Saving the model with 40.54
#
# [Epoch 36]
# Pred: VALLEE | True: VALLEE
# Pred: LECOUVEY | True: LECOUVEY
# Pred: AGUSTIN | True: AUGUSTIN
# Train Loss: 0.7909, Train Acc: 31.55%, Val Loss: 0.7122, Val Acc: 40.34%
#
# [Epoch 37]
# Pred: GUILHARSCHLCLE | True: GUILMARD-SCHLICK
# Pred: DEBOHY | True: DEBOMY
# Pred: ROUSSET | True: ROUSSET
# Train Loss: 0.7342, Train Acc: 35.60%, Val Loss: 0.6495, Val Acc: 44.14%
# Saving the model with 44.14
#
# [Epoch 38]
# Pred: CHIETSTHE | True: CHRISTOPHE
# Pred: ROCHA | True: ROCHA
# Pred: JULES | True: JULES
# Train Loss: 0.6868, Train Acc: 37.26%, Val Loss: 0.6129, Val Acc: 48.55%
# Saving the model with 48.55
#
# [Epoch 39]
# Pred: MAINA | True: MAINA
# Pred: BLANCHART | True: BLANCHART
# Pred: BAVORY | True: BAUDRY
# Train Loss: 0.6529, Train Acc: 40.46%, Val Loss: 0.5962, Val Acc: 46.85%
#
# [Epoch 40]
# Pred: ARTHAHU | True: ARTHAUD
# Pred: MIRANDRCORREIA | True: MIRANDACORREIA
# Pred: MARCEAU | True: MARCEAU
# Train Loss: 0.6325, Train Acc: 40.74%, Val Loss: 0.6265, Val Acc: 45.05%
#
# [Epoch 41]
# Pred: BRIAN | True: BRIAN
# Pred: DARIAC | True: DARZAC
# Pred: COUDOUR | True: COUDOUR
# Train Loss: 0.5997, Train Acc: 44.84%, Val Loss: 0.5772, Val Acc: 50.05%
# Saving the model with 50.05
#
# [Epoch 42]
# Pred: EMY | True: EMY
# Pred: BEANTONI | True: DEANTONI
# Pred: THOMAS | True: THOMAS
# Train Loss: 0.5786, Train Acc: 44.86%, Val Loss: 0.5336, Val Acc: 53.35%
# Saving the model with 53.35
#
# [Epoch 43]
# Pred: FOUQUE | True: FOUQUE
# Pred: DUBOIS | True: DUBOIS
# Pred: SECK | True: SECK
# Train Loss: 0.5725, Train Acc: 46.43%, Val Loss: 0.5565, Val Acc: 52.25%
#
# [Epoch 44]
# Pred: MAELLE | True: MAELLE
# Pred: ELINDA | True: ELINOR
# Pred: MATHILDE | True: MATHILDE
# Train Loss: 0.5493, Train Acc: 48.21%, Val Loss: 0.5421, Val Acc: 53.15%
#
# [Epoch 45]
# Pred: AZMANI | True: AZMANI
# Pred: ANQUET | True: ANQUET
# Pred: OEANE | True: OCEANE
# Train Loss: 0.5329, Train Acc: 48.15%, Val Loss: 0.5310, Val Acc: 54.45%
# Saving the model with 54.45
#
# [Epoch 46]
# Pred: BARAPHAELLE | True: RAPHAELLE
# Pred: NARDUN | True: MARDUN
# Pred: SLAEE | True: CALOEE
# Train Loss: 0.5352, Train Acc: 48.93%, Val Loss: 0.5627, Val Acc: 51.25%
#
# [Epoch 47]
# Pred: FALZARD | True: SALZARD
# Pred: BORDONADO | True: BORDONADO
# Pred: LE ROUX | True: LE ROUX
# Train Loss: 0.5222, Train Acc: 49.65%, Val Loss: 0.5157, Val Acc: 55.56%
# Saving the model with 55.56
#
# [Epoch 48]
# Pred: HADY | True: MABY
# Pred: KAVIER | True: XAVIER
# Pred: NOAM | True: NOAH
# Train Loss: 0.4927, Train Acc: 51.13%, Val Loss: 0.5071, Val Acc: 58.86%
# Saving the model with 58.86
#
# [Epoch 49]
# Pred: CABAVOT | True: CABAYOT
# Pred: FICOT | True: FICOT
# Pred: MAEL | True: MAEL
# Train Loss: 0.4888, Train Acc: 52.43%, Val Loss: 0.5090, Val Acc: 57.56%
#
# [Epoch 50]
# Pred: RENARD | True: RENARD
# Pred: ANNA | True: ANNA
# Pred: JOAN | True: JOAN
# Train Loss: 0.4582, Train Acc: 53.13%, Val Loss: 0.4861, Val Acc: 57.96%
#
# [Epoch 51]
# Pred: EMMA | True: EMMA
# Pred: PUEL | True: PUES
# Pred: MMBTIOND | True: MINGLIANG
# Train Loss: 0.4477, Train Acc: 54.19%, Val Loss: 0.5008, Val Acc: 58.76%
#
# [Epoch 52]
# Pred: JELENA | True: SELENA
# Pred: MATEI | True: MATEI
# Pred: BRETAGNOLLE | True: BRETAGNOLLE
# Train Loss: 0.4367, Train Acc: 54.47%, Val Loss: 0.4838, Val Acc: 59.96%
# Saving the model with 59.96
#
# [Epoch 53]
# Pred: NOLAN | True: NOLAN
# Pred: MAAGANX | True: MARGAUX
# Pred: HUGO | True: HUGO
# Train Loss: 0.4243, Train Acc: 56.46%, Val Loss: 0.4787, Val Acc: 59.26%
#
# [Epoch 54]
# Pred: VICTOR | True: VICTOR
# Pred: GUISERT | True: GUIBERT
# Pred: FAUISKI | True: GDULSKI
# Train Loss: 0.4215, Train Acc: 56.46%, Val Loss: 0.4914, Val Acc: 59.06%
#
# [Epoch 55]
# Pred: SLA | True: SILA
# Pred: LECOULAN | True: LECOULAN
# Pred: RODRIGUES | True: RODRIGUES
# Train Loss: 0.4149, Train Acc: 56.22%, Val Loss: 0.5014, Val Acc: 56.46%
#
# [Epoch 56]
# Pred: VAYE | True: VAYE
# Pred: DELEPBORIE | True: DELEPORTE
# Pred: CHABE | True: CHABOUX
# Train Loss: 0.3996, Train Acc: 57.52%, Val Loss: 0.4864, Val Acc: 61.36%
# Saving the model with 61.36
#
# [Epoch 57]
# Pred: THERON | True: THERON
# Pred: RONAN | True: RONAN
# Pred: EVA | True: EVA
# Train Loss: 0.3928, Train Acc: 57.94%, Val Loss: 0.4815, Val Acc: 60.46%
#
# [Epoch 58]
# Pred: PESCHARD | True: PESCHARD
# Pred: CAHU | True: CAHU
# Pred: LEVETEAU | True: LEVETEAU
# Train Loss: 0.3825, Train Acc: 58.82%, Val Loss: 0.4707, Val Acc: 61.16%
#
# [Epoch 59]
# Pred: LAURAN | True: LAURYN
# Pred: CINDA | True: CINDA
# Pred: FABIEN | True: FABEIN
# Train Loss: 0.3952, Train Acc: 57.98%, Val Loss: 0.4705, Val Acc: 60.26%
#
# [Epoch 60]
# Pred: LAURELEKE | True: LAURECINE
# Pred: JULIETIE | True: JULIETTE
# Pred: HURAND | True: DURAND
# Train Loss: 0.3769, Train Acc: 59.62%, Val Loss: 0.4723, Val Acc: 62.26%
# Saving the model with 62.26
#
# [Epoch 61]
# Pred: STEVEN | True: STEVEN
# Pred: ROMAIN | True: ROMAIN
# Pred: TOUIL | True: TOUIL
# Train Loss: 0.3689, Train Acc: 59.88%, Val Loss: 0.4826, Val Acc: 58.66%
#
# [Epoch 62]
# Pred: MATTHIEU | True: MATTHIEU
# Pred: LOZES | True: LOZES
# Pred: CHARLY | True: CHARLY
# Train Loss: 0.3663, Train Acc: 60.28%, Val Loss: 0.4600, Val Acc: 62.76%
# Saving the model with 62.76
#
# [Epoch 63]
# Pred: KOCH | True: KOCH
# Pred: RIAMI | True: RIAHI
# Pred: GUILHARD-SCHUEL | True: GUILMARD-SCHLICK
# Train Loss: 0.3575, Train Acc: 62.02%, Val Loss: 0.4591, Val Acc: 62.56%
#
# [Epoch 64]
# Pred: TOURNIER | True: TOURNIER
# Pred: BABTIEN | True: BASTIEN
# Pred: NICOLAS | True: NICOLAS
# Train Loss: 0.3541, Train Acc: 60.66%, Val Loss: 0.4887, Val Acc: 61.16%
#
# [Epoch 65]
# Pred: NMY | True: EMPTY
# Pred: CLARISSE | True: CLARISSE
# Pred: RAPHHEL | True: RAPHAEL
# Train Loss: 0.3473, Train Acc: 61.32%, Val Loss: 0.4872, Val Acc: 60.76%
#
# [Epoch 66]
# Pred: SRICARDA | True: RICARDO
# Pred: MORANT | True: MORANT
# Pred: KINGUE | True: KINGUE
# Train Loss: 0.3312, Train Acc: 62.64%, Val Loss: 0.4839, Val Acc: 60.96%
#
# [Epoch 67]
# Pred: TROISPOUX | True: TROISPOUX
# Pred: DAUMONT | True: DAUMONT
# Pred: BECHEUR | True: BECHENR
# Train Loss: 0.3377, Train Acc: 63.10%, Val Loss: 0.4701, Val Acc: 62.26%
#
# [Epoch 68]
# Pred: DAVID | True: DAVID
# Pred: VERVAECKE | True: VERVAECKE
# Pred: ARGO | True: LARGO
# Train Loss: 0.3331, Train Acc: 62.84%, Val Loss: 0.4908, Val Acc: 59.86%
#
# [Epoch 69]
# Pred: LOANE | True: LOANE
# Pred: WIIBIZIGIRWA | True: NIBIZIGIRWA
# Pred: YOAN | True: YOAN
# Train Loss: 0.3280, Train Acc: 63.04%, Val Loss: 0.4534, Val Acc: 63.96%
# Saving the model with 63.96
#
# [Epoch 70]
# Pred: DAIGUEMORTE | True: DAIGUEMORTE
# Pred: ASTRID | True: ASTRID
# Pred: OSORIO | True: OSORIO
# Train Loss: 0.3047, Train Acc: 64.84%, Val Loss: 0.4574, Val Acc: 64.26%
# Saving the model with 64.26
#
# [Epoch 71]
# Pred: HUGO | True: HUGO
# Pred: BERARD | True: BERARD
# Pred: BASTIEN | True: BASTIEN
# Train Loss: 0.3046, Train Acc: 65.71%, Val Loss: 0.4547, Val Acc: 62.76%
#
# [Epoch 72]
# Pred: MOUJAHID | True: MOUJAHID
# Pred: BASSENT | True: RASSENT
# Pred: SONIA | True: SONIA
# Train Loss: 0.3170, Train Acc: 64.12%, Val Loss: 0.4801, Val Acc: 61.86%
#
# [Epoch 73]
# Pred: SUCH | True: SUCH
# Pred: LAUZETTE | True: LAURETTE
# Pred: LINA | True: LINA
# Train Loss: 0.3001, Train Acc: 64.48%, Val Loss: 0.4573, Val Acc: 63.26%
#
# [Epoch 74]
# Pred: MATIN | True: HARIN
# Pred: BOUAOU | True: BOUAOU
# Pred: JEMUME | True: JERUME
# Train Loss: 0.3015, Train Acc: 64.60%, Val Loss: 0.4711, Val Acc: 61.56%
#
# [Epoch 75]
# Pred: BUSINELLI | True: BUSINELLI
# Pred: JACINTO | True: JACINTO
# Pred: GILORPE | True: GLOPPE
# Train Loss: 0.3007, Train Acc: 65.19%, Val Loss: 0.4778, Val Acc: 63.76%
#
# [Epoch 76]
# Pred: NAITSIDI AHMED | True: NAIT SIDI AHMED
# Pred: EVE | True: EVE
# Pred: GABANACK | True: CABANACQ
# Train Loss: 0.2960, Train Acc: 64.92%, Val Loss: 0.4616, Val Acc: 64.86%
# Saving the model with 64.86
#
# [Epoch 77]
# Pred: ROMAID | True: ROMAIN
# Pred: BERRONNG | True: PERRONNO
# Pred: THOMAS | True: THOMAS
# Train Loss: 0.2827, Train Acc: 66.33%, Val Loss: 0.4737, Val Acc: 61.56%
#
# [Epoch 78]
# Pred: AIGRAINE | True: MIGRAINE
# Pred: BAHLOUL | True: BAHLOUL
# Pred: CUESTA | True: CUESTA
# Train Loss: 0.2903, Train Acc: 65.31%, Val Loss: 0.4744, Val Acc: 62.86%
#
# [Epoch 79]
# Pred: SUMTITH | True: SUMTITH
# Pred: EATA | True: BATA
# Pred: EMMA | True: EMMA
# Train Loss: 0.2738, Train Acc: 65.93%, Val Loss: 0.4578, Val Acc: 64.26%
#
# [Epoch 80]
# Pred: TRAUERSE | True: TRAVERSE
# Pred: FABRE | True: FABRE
# Pred: VICTOR | True: VICTOR
# Train Loss: 0.2875, Train Acc: 66.15%, Val Loss: 0.4516, Val Acc: 64.86%
#
# [Epoch 81]
# Pred: LOUIS | True: LOUIS
# Pred: ILLANA | True: ILLANA
# Pred: RAYAN | True: RAYAN
# Train Loss: 0.2621, Train Acc: 68.59%, Val Loss: 0.5111, Val Acc: 56.66%
#
# [Epoch 82]
# Pred: E | True: EMPTY
# Pred: LANGLOIS | True: LANGLOIS
# Pred: LE BRIS | True: LE BRIS
# Train Loss: 0.2565, Train Acc: 68.65%, Val Loss: 0.5207, Val Acc: 59.66%
#
# [Epoch 83]
# Pred: MORGAN | True: MORGAN
# Pred: FISCHER | True: FISCHER
# Pred: NAWEL | True: NAWEL
# Train Loss: 0.2543, Train Acc: 69.09%, Val Loss: 0.4622, Val Acc: 63.66%
#
# [Epoch 84]
# Pred: ANTONE | True: ANTONE
# Pred: SHAMA LESLIE | True: SHAMA LESLIE
# Pred: GUIGUE | True: GUIGUE
# Train Loss: 0.2443, Train Acc: 69.19%, Val Loss: 0.4725, Val Acc: 63.26%
#
# [Epoch 85]
# Pred: LUCIS | True: LUCIC
# Pred: VICTORIA | True: VICTORIA
# Pred: LOLWENN | True: NOLWENN
# Train Loss: 0.2478, Train Acc: 69.61%, Val Loss: 0.4465, Val Acc: 63.96%
#
# [Epoch 86]
# Pred: KUBEREK | True: KUBEREK
# Pred: SEROT | True: SEROT
# Pred: JOAH | True: JOAH
# Train Loss: 0.2533, Train Acc: 68.55%, Val Loss: 0.4650, Val Acc: 64.36%
#
# [Epoch 87]
# Pred: AGNESA | True: AGNESA
# Pred: MELISSA | True: MELISSA
# Pred: LERAT | True: LERAT
# Train Loss: 0.2508, Train Acc: 68.35%, Val Loss: 0.4632, Val Acc: 63.76%
#
# [Epoch 88]
# Pred: AYEUL | True: MAYEUL
# Pred: FEREMY | True: GEREMY
# Pred: BORSON | True: BORSON
# Train Loss: 0.2500, Train Acc: 69.89%, Val Loss: 0.4529, Val Acc: 66.47%
# Saving the model with 66.47
#
# [Epoch 89]
# Pred: CLEMEAT | True: CLEMENT
# Pred: SAILLON | True: SAILLON
# Pred: NICOLAS | True: NICOLAS
# Train Loss: 0.2403, Train Acc: 70.01%, Val Loss: 0.4824, Val Acc: 63.46%
#
# [Epoch 90]
# Pred: ADRIEN | True: ADRIEN
# Pred: ALIX | True: ALIX
# Pred: ROYANE | True: ROXANE
# Train Loss: 0.2858, Train Acc: 66.33%, Val Loss: 0.4706, Val Acc: 64.06%
#
# [Epoch 91]
# Pred: BENCHEIKM | True: BENCHEIKH
# Pred: BEYMKI | True: REYNAL
# Pred: RENAULT | True: RENAULT
# Train Loss: 0.2505, Train Acc: 69.11%, Val Loss: 0.4852, Val Acc: 61.76%
#
# [Epoch 92]
# Pred: AOPMIE | True: SOPHIE
# Pred: AMARA | True: AMARA
# Pred: ADELYS | True: ADELYS
# Train Loss: 0.2511, Train Acc: 68.67%, Val Loss: 0.5183, Val Acc: 60.06%
#
# [Epoch 93]
# Pred: CLEEM | True: CLEMENET
# Pred: DELORME | True: DELORME
# Pred: BRISARD | True: BRISARD
# Train Loss: 0.2607, Train Acc: 68.33%, Val Loss: 0.4781, Val Acc: 62.56%
#
# [Epoch 94]
# Pred: TREMEIN | True: TREHEIN
# Pred: BEANTONI | True: DEANTONI
# Pred: REVET | True: REVET
# Train Loss: 0.2254, Train Acc: 70.97%, Val Loss: 0.4854, Val Acc: 64.06%
#
# [Epoch 95]
# Pred: BEMUET | True: BEHUET
# Pred: AWAYOGU | True: AWAYOGO
# Pred: LIGGEOIS | True: LIGGEOIS
# Train Loss: 0.2231, Train Acc: 71.25%, Val Loss: 0.4732, Val Acc: 64.16%
#
# [Epoch 96]
# Pred: HUGO | True: HUGO
# Pred: MYLENE | True: HYLENE
# Pred: NICOLAS | True: NICOLAS
# Train Loss: 0.2512, Train Acc: 69.41%, Val Loss: 0.4654, Val Acc: 63.36%
#
# [Epoch 97]
# Pred: KEAZEM | True: KENZEM
# Pred: LUCIE | True: LUCIE
# Pred: THEO | True: THEO
# Train Loss: 0.2134, Train Acc: 71.65%, Val Loss: 0.4736, Val Acc: 64.16%
#
# [Epoch 98]
# Pred: PIELRE | True: PIERRE
# Pred: EMILIEN | True: EMILIEN
# Pred: MOUMEAU | True: HOUMEAU
# Train Loss: 0.2193, Train Acc: 71.63%, Val Loss: 0.4846, Val Acc: 62.06%
#
# [Epoch 99]
# Pred: PAULINE | True: PAULINE
# Pred: BAPTISTE | True: BAPTISTE
# Pred: TASMVIA | True: THOMAS
# Train Loss: 0.2191, Train Acc: 72.41%, Val Loss: 0.4763, Val Acc: 63.66%
#
# [Epoch 100]
# Pred: CHRISTOPHE | True: CHRISTOPHE
# Pred: NATAN | True: NATAN
# Pred: ROGUARD | True: EDOUARD
# Train Loss: 0.2227, Train Acc: 71.45%, Val Loss: 0.4658, Val Acc: 62.16%
#
# [Epoch 101]
# Pred: BOUMADDAOJ | True: BOUHADHAOJ
# Pred: EMMA | True: EMMA
# Pred: DUUET | True: DUVET
# Train Loss: 0.2160, Train Acc: 72.49%, Val Loss: 0.4666, Val Acc: 65.07%
#
# [Epoch 102]
# Pred: NICOLAS | True: NICOLAS
# Pred: CAROLANE | True: CAROLANE
# Pred: ADNANE | True: ADNANE
# Train Loss: 0.2101, Train Acc: 72.37%, Val Loss: 0.4631, Val Acc: 65.87%
#
# [Epoch 103]
# Pred: CMARLOTTE | True: CHARLOTTE
# Pred: COMTE | True: COMTE
# Pred: JOUSEAU | True: JOUSEAU
# Train Loss: 0.1950, Train Acc: 74.27%, Val Loss: 0.4715, Val Acc: 62.56%
#
# [Epoch 104]
# Pred: ZULIAN | True: ZULIAN
# Pred: EOSTHER | True: ESTHER
# Pred: MATHYS | True: MATHYS
# Train Loss: 0.2021, Train Acc: 72.55%, Val Loss: 0.4579, Val Acc: 65.57%
#
# [Epoch 105]
# Pred: ALLIE | True: ALLIE
# Pred: YANIS | True: YANIS
# Pred: NDABAGERA | True: NDABAGERA
# Train Loss: 0.2028, Train Acc: 72.81%, Val Loss: 0.4647, Val Acc: 64.36%
#
# [Epoch 106]
# Pred: JADE | True: JADE
# Pred: FORCE- SPENCER | True: FORCE SPENCER
# Pred: CLEMENCE | True: CLEMENCE
# Train Loss: 0.1988, Train Acc: 73.87%, Val Loss: 0.4703, Val Acc: 64.76%
#
# [Epoch 107]
# Pred: SALHA | True: SACHA
# Pred: JOAN | True: JOAN
# Pred: MATHIEU | True: MATHIEU
# Train Loss: 0.1948, Train Acc: 73.81%, Val Loss: 0.4911, Val Acc: 64.46%
#
# [Epoch 108]
# Pred: BRAYAN | True: BRAYAN
# Pred: HAUVILLE | True: HAUVILLE
# Pred: IMON | True: SIMON
# Train Loss: 0.2033, Train Acc: 72.43%, Val Loss: 0.4839, Val Acc: 64.66%
#
# [Epoch 109]
# Pred: ALYES | True: ALVES
# Pred: SARAGOSLI | True: SARAGOSLI
# Pred: AUDISSO | True: AUDISSO
# Train Loss: 0.1916, Train Acc: 73.81%, Val Loss: 0.4852, Val Acc: 65.57%
#
# [Epoch 110]
# Pred: BAMONIO | True: BAMONIO
# Pred: COSSA | True: COSSA
# Pred: DUAULT | True: DUAULT
# Train Loss: 0.1856, Train Acc: 74.75%, Val Loss: 0.4961, Val Acc: 64.06%
#
# [Epoch 111]
# Pred: CIBIER | True: GIBIER
# Pred: ROWALSKI | True: KOWALSKI
# Pred: EMELINE | True: EMELINE
# Train Loss: 0.1843, Train Acc: 74.47%, Val Loss: 0.4962, Val Acc: 63.46%
#
# [Epoch 112]
# Pred: LOUIS | True: LOUIS
# Pred: CHARRIN | True: CHARRIN
# Pred: JOURNO | True: JOURNO
# Train Loss: 0.2317, Train Acc: 70.29%, Val Loss: 0.5245, Val Acc: 62.46%
#
# [Epoch 113]
# Pred: LEFEVRE | True: LEFEVRE
# Pred: ACHILLE | True: ACHILLE
# Pred: BAISSIERES | True: BAISSIERES
# Train Loss: 0.1946, Train Acc: 73.41%, Val Loss: 0.4887, Val Acc: 64.66%
#
# [Epoch 114]
# Pred: SALMAN | True: SALMAN
# Pred: ALINE | True: ALINE
# Pred: TOURNIER | True: TOURNIER
# Train Loss: 0.1805, Train Acc: 75.32%, Val Loss: 0.5283, Val Acc: 61.16%
#
# [Epoch 115]
# Pred: SAFSAG | True: SAFSAG
# Pred: TOHAHES | True: YOHANES
# Pred: THEO | True: THEO
# Train Loss: 0.1829, Train Acc: 74.97%, Val Loss: 0.4772, Val Acc: 66.67%
# Saving the model with 66.67
#
# [Epoch 116]
# Pred: RIBEIRO | True: RIBEIRO
# Pred: OOOPER | True: COOPER
# Pred: LENNY | True: LENNY
# Train Loss: 0.1737, Train Acc: 75.94%, Val Loss: 0.4898, Val Acc: 66.67%
#
# [Epoch 117]
# Pred: SHESSAERT | True: SMESSAERT
# Pred: TIAGO | True: TIAGO
# Pred: LOUIS | True: LOUIS
# Train Loss: 0.1859, Train Acc: 74.23%, Val Loss: 0.5101, Val Acc: 65.07%
#
# [Epoch 118]
# Pred: ULYSSE | True: ULYSSE
# Pred: MERIIN | True: MERLIN
# Pred: LE QUERE | True: LE QUERE
# Train Loss: 0.1773, Train Acc: 75.42%, Val Loss: 0.5240, Val Acc: 62.26%
#
# [Epoch 119]
# Pred: PERRIER | True: PERRIER
# Pred: LOUIIE | True: LOUISE
# Pred: LEMOINE | True: LEMOINE
# Train Loss: 0.1802, Train Acc: 74.53%, Val Loss: 0.4701, Val Acc: 65.87%
#
# [Epoch 120]
# Pred: LOE | True: LOE
# Pred: RONANE | True: ROXANE
# Pred: THEMG | True: THEME
# Train Loss: 0.1736, Train Acc: 75.82%, Val Loss: 0.5023, Val Acc: 62.76%
#
# [Epoch 121]
# Pred: RYMARCZYR | True: RYMANCZYK
# Pred: UGO | True: UGO
# Pred: BOUTET | True: BOUTET
# Train Loss: 0.1821, Train Acc: 74.01%, Val Loss: 0.4836, Val Acc: 66.07%
#
# [Epoch 122]
# Pred: REDA | True: REDA
# Pred: GIANNE | True: GIANNI
# Pred: ANDRE | True: ANDRE
# Train Loss: 0.1709, Train Acc: 76.48%, Val Loss: 0.5126, Val Acc: 62.96%
#
# [Epoch 123]
# Pred: YOANN | True: YOANN
# Pred: OXCEANE | True: OCEANE
# Pred: ALBERQUILLA | True: ALBERQUILLA
# Train Loss: 0.1852, Train Acc: 74.71%, Val Loss: 0.5083, Val Acc: 63.46%
#
# [Epoch 124]
# Pred: BAULINE | True: PAULINE
# Pred: ELOI | True: ELOI
# Pred: UTILLE | True: UTILLE
# Train Loss: 0.1678, Train Acc: 75.90%, Val Loss: 0.4855, Val Acc: 65.07%
#
# [Epoch 125]
# Pred: PONCHON | True: PONCHON
# Pred: SAEZ | True: SAEZ
# Pred: VAYE | True: VAYE
# Train Loss: 0.1790, Train Acc: 76.08%, Val Loss: 0.5009, Val Acc: 64.36%
#
# [Epoch 126]
# Pred: GIARCES | True: GEORGES
# Pred: LEPETIT | True: LEPETIT
# Pred: GENNARO | True: GENNARO
# Train Loss: 0.1752, Train Acc: 75.74%, Val Loss: 0.4986, Val Acc: 63.86%
#
# [Epoch 127]
# Pred: GENNARD | True: GENNARO
# Pred: DEJESUSTEIXIIRA | True: DEJESUSTEIXEIRA
# Pred: MAXENCE | True: MAXENCE
# Train Loss: 0.1717, Train Acc: 76.12%, Val Loss: 0.4870, Val Acc: 64.96%
#
# [Epoch 128]
# Pred: HONORE HUET | True: HONORE MUET
# Pred: SUSAN | True: SUSAN
# Pred: BRRICE | True: BRICE
# Train Loss: 0.1689, Train Acc: 76.22%, Val Loss: 0.5004, Val Acc: 64.46%
#
# [Epoch 129]
# Pred: ELISA | True: ELISA
# Pred: DEMALLYDESSAINA | True: DEMALLYDESSAINT
# Pred: LILON | True: LILOU
# Train Loss: 0.1819, Train Acc: 75.28%, Val Loss: 0.5097, Val Acc: 65.37%
#
# [Epoch 130]
# Pred: THEEBLINCE | True: THEEBLYNCK
# Pred: ZAYNATI | True: ZAHNATI
# Pred: NASSIM | True: NASSIM
# Train Loss: 0.1669, Train Acc: 76.40%, Val Loss: 0.4870, Val Acc: 66.57%
#
# [Epoch 131]
# Pred: CHRUSCIEL | True: CHRUSCIEL
# Pred: FREHOND | True: FREHOND
# Pred: PERRIER | True: PERRIER
# Train Loss: 0.1608, Train Acc: 77.24%, Val Loss: 0.4963, Val Acc: 63.86%
#
# [Epoch 132]
# Pred: NAEVA | True: NEVA
# Pred: DUR | True: DUR
# Pred: LILOU | True: LILOU
# Train Loss: 0.1484, Train Acc: 78.36%, Val Loss: 0.4808, Val Acc: 67.27%
# Saving the model with 67.27
#
# [Epoch 133]
# Pred: PARENT | True: PARENT
# Pred: LECONTE | True: LECONTE
# Pred: ESTERHNN | True: ESTEBANN
# Train Loss: 0.1646, Train Acc: 76.88%, Val Loss: 0.4990, Val Acc: 63.86%
#
# [Epoch 134]
# Pred: ELISA | True: ELISA
# Pred: TURBE | True: TURBE
# Pred: DRSLAN | True: DYLAN
# Train Loss: 0.2325, Train Acc: 69.07%, Val Loss: 0.5017, Val Acc: 65.47%
#
# [Epoch 135]
# Pred: TACOO | True: JACOB
# Pred: GAETAN | True: GAETAN
# Pred: CAFFORELLI | True: GAFFORELLI
# Train Loss: 0.1883, Train Acc: 75.24%, Val Loss: 0.4885, Val Acc: 66.47%
#
# [Epoch 136]
# Pred: LOU-ANN | True: LOU-ANN
# Pred: ERRAM | True: ELRAM
# Pred: PAULINE | True: PAULINE
# Train Loss: 0.1819, Train Acc: 74.57%, Val Loss: 0.5024, Val Acc: 65.87%
#
# [Epoch 137]
# Pred: LAUAUNE | True: LAURYNE
# Pred: LOUBENAZ | True: LOUVENAZ
# Pred: GEYER | True: GEYER
# Train Loss: 0.1625, Train Acc: 78.02%, Val Loss: 0.5145, Val Acc: 65.27%
#
# [Epoch 138]
# Pred: RONIEUX | True: ROMIEUX
# Pred: CASSIE | True: CASSIE
# Pred: CARRAT | True: CARRAT
# Train Loss: 0.1533, Train Acc: 78.18%, Val Loss: 0.4951, Val Acc: 66.27%
#
# [Epoch 139]
# Pred: RENAULT | True: RENAULT
# Pred: THIBAULT | True: THIBAULT
# Pred: OBERHAUSER | True: OBERHAUSER
# Train Loss: 0.1492, Train Acc: 77.84%, Val Loss: 0.4693, Val Acc: 68.77%
# Saving the model with 68.77
#
# [Epoch 140]
# Pred: ELIA | True: ELIA
# Pred: MARIELLA | True: MARIELLA
# Pred: CAILLOCE | True: CAILLOCE
# Train Loss: 0.1451, Train Acc: 79.00%, Val Loss: 0.4857, Val Acc: 67.77%
#
# [Epoch 141]
# Pred: ESTEBAN | True: ESTEBAN
# Pred: BROCHET | True: BROCHET
# Pred: SOLEN | True: SOLEN
# Train Loss: 0.1663, Train Acc: 76.28%, Val Loss: 0.5009, Val Acc: 63.46%
#
# [Epoch 142]
# Pred: KAMANSKI | True: KAMINSKI
# Pred: GAUTIER | True: GAUTHIER
# Pred: MAHU | True: MAHU
# Train Loss: 0.1522, Train Acc: 77.98%, Val Loss: 0.4998, Val Acc: 65.47%
#
# [Epoch 143]
# Pred: BENJAMIN | True: BENJAMIN
# Pred: BENARD | True: BCNARD
# Pred: SANA | True: SANA
# Train Loss: 0.1582, Train Acc: 77.38%, Val Loss: 0.5171, Val Acc: 62.86%
#
# [Epoch 144]
# Pred: VISIEDO | True: VISIEDO
# Pred: ELMOUMI | True: ELMOUMI
# Pred: SOUAD | True: SOUAD
# Train Loss: 0.1886, Train Acc: 74.31%, Val Loss: 0.4976, Val Acc: 64.46%
#
# [Epoch 145]
# Pred: WAKIM | True: WAKIM
# Pred: LAURA | True: LAURA
# Pred: TOM | True: TOM
# Train Loss: 0.1464, Train Acc: 79.12%, Val Loss: 0.4828, Val Acc: 66.37%
#
# [Epoch 146]
# Pred: EMILE | True: EMILE
# Pred: CABANAEY | True: CABANACQ
# Pred: MUSIAL | True: MUSIAL
# Train Loss: 0.1395, Train Acc: 79.56%, Val Loss: 0.4815, Val Acc: 66.77%
#
# [Epoch 147]
# Pred: LOUIS | True: LOUIS
# Pred: DUBARRY | True: DUBARRY
# Pred: LEA | True: LEA
# Train Loss: 0.1458, Train Acc: 78.00%, Val Loss: 0.4997, Val Acc: 66.37%
#
# [Epoch 148]
# Pred: DI LLANNE | True: GU LLAUNE
# Pred: SANA | True: SANA
# Pred: CANOO | True: GANOO
# Train Loss: 0.1335, Train Acc: 80.50%, Val Loss: 0.4900, Val Acc: 67.07%
#
# [Epoch 149]
# Pred: POILNET | True: POILVET
# Pred: DAVID | True: DAVID
# Pred: NOELIE | True: NOELIE
# Train Loss: 0.1568, Train Acc: 77.04%, Val Loss: 0.5216, Val Acc: 65.87%
#
# [Epoch 150]
# Pred: MEURIE | True: MEURIE
# Pred: CHLOE | True: CHLOE
# Pred: MAREO-JOBERT | True: CAREO-JOBERT
# Train Loss: 0.1539, Train Acc: 77.38%, Val Loss: 0.5226, Val Acc: 65.07%
#
# [Epoch 151]
# Pred: ALICE | True: ALICE
# Pred: LANGLOIS | True: LANGLOIS
# Pred: MULLER | True: MULLER
# Train Loss: 0.1498, Train Acc: 78.16%, Val Loss: 0.5016, Val Acc: 66.67%
#
# [Epoch 152]
# Pred: MANHES | True: MANHES
# Pred: JACQ | True: JACQ
# Pred: TRECA | True: TRECA
# Train Loss: 0.1481, Train Acc: 79.12%, Val Loss: 0.5079, Val Acc: 65.47%
#
# [Epoch 153]
# Pred: THIBAUD | True: THIBAUD
# Pred: CLEMENET | True: CLEMENET
# Pred: HUGO | True: HUGO
# Train Loss: 0.1406, Train Acc: 78.94%, Val Loss: 0.5116, Val Acc: 67.17%
#
# [Epoch 154]
# Pred: PICHON | True: PICHON
# Pred: JADE | True: JADE
# Pred: NICOLAS | True: NICOLAS
# Train Loss: 0.1438, Train Acc: 78.38%, Val Loss: 0.4921, Val Acc: 66.57%
#
# [Epoch 155]
# Pred: ALIX | True: ALIX
# Pred: MATHILDE | True: MATHILDE
# Pred: PERKINS | True: PERKINS
# Train Loss: 0.1438, Train Acc: 78.50%, Val Loss: 0.4989, Val Acc: 65.77%
#
# [Epoch 156]
# Pred: CHAPELLIER | True: CHAPELLIER
# Pred: MATHIAS | True: MATHIAS
# Pred: GRIHARD | True: GRIHARD
# Train Loss: 0.1415, Train Acc: 79.10%, Val Loss: 0.5260, Val Acc: 67.27%
#
# [Epoch 157]
# Pred: MONMERT | True: HONNERT
# Pred: DE VISMES | True: DE VISMES
# Pred: ROOSE | True: ROOSE
# Train Loss: 0.1395, Train Acc: 78.96%, Val Loss: 0.5196, Val Acc: 65.77%
#
# [Epoch 158]
# Pred: FOXONET | True: FOXONET
# Pred: BERGEAULT | True: BERGEAULT
# Pred: AYECH | True: AYECH
# Train Loss: 0.1416, Train Acc: 78.80%, Val Loss: 0.4929, Val Acc: 67.77%
#
# [Epoch 159]
# Pred: VICTORIA | True: VICTORIA
# Pred: MALO | True: MALO
# Pred: JULIETTE | True: JULIETTE
# Train Loss: 0.1482, Train Acc: 78.20%, Val Loss: 0.4920, Val Acc: 66.77%
#
# [Epoch 160]
# Pred: HOUL | True: HOUL
# Pred: BAILLEUX | True: BAILLEUX
# Pred: YOUSSEF | True: YOUSSEF
# Train Loss: 0.1354, Train Acc: 80.12%, Val Loss: 0.5052, Val Acc: 67.17%
#
# [Epoch 161]
# Pred: JAUREGUIBEREY | True: JAUREGUIBERRY
# Pred: THEO | True: THEO
# Pred: TESEU-AAILY | True: TESTU-HALLEY
# Train Loss: 0.1394, Train Acc: 79.56%, Val Loss: 0.5134, Val Acc: 67.07%
#
# [Epoch 162]
# Pred: AMBRE | True: AMBRE
# Pred: MAEHA | True: MAUD
# Pred: LECLOIREC | True: LECLOIREL
# Train Loss: 0.1616, Train Acc: 77.16%, Val Loss: 0.4931, Val Acc: 66.17%
#
# [Epoch 163]
# Pred: FLORIAN | True: FLORIAN
# Pred: GLENAT | True: GLENAT
# Pred: LE QUERE | True: LE QUERE
# Train Loss: 0.1564, Train Acc: 77.92%, Val Loss: 0.4967, Val Acc: 67.77%
#
# [Epoch 164]
# Pred: MAMENEE | True: MAXENEE
# Pred: FONCAULR | True: FOUCAULD
# Pred: ALOIS | True: ALOIS
# Train Loss: 0.1762, Train Acc: 75.56%, Val Loss: 0.5172, Val Acc: 65.57%
#
# [Epoch 165]
# Pred: MATRAS | True: MATRAS
# Pred: ANCZYROWSKI | True: ANCZYKOWSKI
# Pred: JIRISS | True: IDRISS
# Train Loss: 0.1515, Train Acc: 78.20%, Val Loss: 0.5181, Val Acc: 66.57%
#
# [Epoch 166]
# Pred: REDOUANE | True: REDOUANE
# Pred: DESSALLES | True: DESSALLES
# Pred: MARIE | True: MARIE
# Train Loss: 0.1456, Train Acc: 78.60%, Val Loss: 0.5375, Val Acc: 63.76%
#
# [Epoch 167]
# Pred: ANNE | True: ANNE
# Pred: LAUMET | True: LAUMET
# Pred: MAELLE | True: MAELLE
# Train Loss: 0.1330, Train Acc: 80.04%, Val Loss: 0.5129, Val Acc: 66.17%
#
# [Epoch 168]
# Pred: JADE | True: JADE
# Pred: SEBASTIAN | True: SEBASTIAN
# Pred: PAULIS | True: MAYLIS
# Train Loss: 0.1322, Train Acc: 80.48%, Val Loss: 0.5060, Val Acc: 66.07%
#
# [Epoch 169]
# Pred: AZHERIC | True: AZHERIC
# Pred: ARNODA | True: ARNODO
# Pred: TAGLIAFZCO | True: TAGLIAFICO
# Train Loss: 0.1300, Train Acc: 79.78%, Val Loss: 0.5080, Val Acc: 66.57%
#
# [Epoch 170]
# Pred: MALOLEPSZY | True: MALOLEPSZY
# Pred: FLORIAN | True: FLORIAN
# Pred: DOS-SANTOS | True: DOS-SANTOS
# Train Loss: 0.1256, Train Acc: 81.48%, Val Loss: 0.5001, Val Acc: 69.37%
# Saving the model with 69.37
#
# [Epoch 171]
# Pred: GOBINET | True: GOBINET
# Pred: MAGE | True: MAGE
# Pred: LONGO | True: LONGO
# Train Loss: 0.1246, Train Acc: 80.92%, Val Loss: 0.5068, Val Acc: 68.47%
#
# [Epoch 172]
# Pred: KERYANE | True: KERYANE
# Pred: LEA | True: LEA
# Pred: CAMILLE | True: CAMILLE
# Train Loss: 0.1257, Train Acc: 80.90%, Val Loss: 0.4987, Val Acc: 68.17%
#
# [Epoch 173]
# Pred: FABIO | True: FABIO
# Pred: LAUMET | True: LAUMET
# Pred: CABAYOT | True: CABAYOT
# Train Loss: 0.1267, Train Acc: 81.20%, Val Loss: 0.4999, Val Acc: 66.97%
#
# [Epoch 174]
# Pred: UCUN | True: URCUN
# Pred: ELE | True: EFE
# Pred: CLARA | True: CLARA
# Train Loss: 0.1201, Train Acc: 82.14%, Val Loss: 0.5156, Val Acc: 66.17%
#
# [Epoch 175]
# Pred: FREMI EUX | True: CREMI EUX
# Pred: TOM | True: TOM
# Pred: ZOUAL | True: ZOUAI
# Train Loss: 0.1417, Train Acc: 78.76%, Val Loss: 0.5164, Val Acc: 66.07%
#
# [Epoch 176]
# Pred: BLANCHETON | True: BLANCHETON
# Pred: AMAUDRIC | True: AMAUDRIC
# Pred: EVAN | True: EVAN
# Train Loss: 0.1398, Train Acc: 80.10%, Val Loss: 0.5223, Val Acc: 66.67%
#
# [Epoch 177]
# Pred: LOUIS | True: LOUIS
# Pred: ALISON | True: ALISON
# Pred: CASSANDRA | True: CASSANDRA
# Train Loss: 0.1277, Train Acc: 79.84%, Val Loss: 0.5027, Val Acc: 66.97%
#
# [Epoch 178]
# Pred: ELMAIRE | True: DELMAIRE
# Pred: SOLINE | True: SOLINE
# Pred: NINON | True: NINON
# Train Loss: 0.1264, Train Acc: 80.42%, Val Loss: 0.5312, Val Acc: 66.77%
#
# [Epoch 179]
# Pred: EMELYNE | True: EMELYNE
# Pred: JULIETTE | True: JULIETTE
# Pred: AVELLZUO | True: AVELLINO
# Train Loss: 0.1489, Train Acc: 77.76%, Val Loss: 0.5630, Val Acc: 64.46%
#
# [Epoch 180]
# Pred: LISA | True: LISA
# Pred: MARTIN | True: MARTIN
# Pred: FABIO | True: FABIO
# Train Loss: 0.1622, Train Acc: 77.40%, Val Loss: 0.5107, Val Acc: 67.57%
#
# [Epoch 181]
# Pred: ENZO | True: ENZO
# Pred: BERARD | True: BERARD
# Pred: CHENTOUX | True: CHENTOUF
# Train Loss: 0.1251, Train Acc: 80.06%, Val Loss: 0.5144, Val Acc: 67.77%
#
# [Epoch 182]
# Pred: LEPPENS | True: LIPPENS
# Pred: ANNE HELENE | True: ANNE-HELENE
# Pred: JGANNE | True: JEANNE
# Train Loss: 0.1224, Train Acc: 81.16%, Val Loss: 0.5205, Val Acc: 66.37%
#
# [Epoch 183]
# Pred: ANCIAUX | True: ANCIAUX
# Pred: BRIST | True: BRIOT
# Pred: LEO | True: LEO
# Train Loss: 0.1402, Train Acc: 80.08%, Val Loss: 0.5026, Val Acc: 67.37%
#
# [Epoch 184]
# Pred: NOM | True: NOA
# Pred: THOMAS | True: THOMAS
# Pred: DUBOIS | True: DUBOIS
# Train Loss: 0.1352, Train Acc: 79.52%, Val Loss: 0.4976, Val Acc: 67.47%
#
# [Epoch 185]
# Pred: DILOOUH | True: DIOOUH
# Pred: CAWARA | True: CANARA
# Pred: LEA | True: LEA
# Train Loss: 0.1415, Train Acc: 79.58%, Val Loss: 0.4997, Val Acc: 67.47%
#
# [Epoch 186]
# Pred: CAUALIER | True: CAVALIER
# Pred: TAZOUADIENE | True: IDJOUADIENE
# Pred: GUILLBT | True: GUILLET
# Train Loss: 0.1509, Train Acc: 77.12%, Val Loss: 0.5149, Val Acc: 66.37%
#
# [Epoch 187]
# Pred: DAUMESNIL | True: DAUMESNIL
# Pred: LUCILE | True: LUCILE
# Pred: TANAIS | True: TANAIS
# Train Loss: 0.1327, Train Acc: 79.90%, Val Loss: 0.5239, Val Acc: 65.77%
#
# [Epoch 188]
# Pred: GARDON | True: GARDON
# Pred: SAINT-A-GNAN | True: SAINT-AIGNAN
# Pred: CAROLINE | True: CAROLINE
# Train Loss: 0.1294, Train Acc: 80.46%, Val Loss: 0.5141, Val Acc: 65.47%
#
# [Epoch 189]
# Pred: GRAHOU | True: GBAHOU
# Pred: ALAN | True: ALAN
# Pred: JADE | True: JADW
# Train Loss: 0.1179, Train Acc: 82.06%, Val Loss: 0.5294, Val Acc: 66.97%
#
# [Epoch 190]
# Pred: CELIA | True: CELIA
# Pred: ALBANE | True: ALBANE
# Pred: MANEL | True: MANEL
# Train Loss: 0.1415, Train Acc: 78.36%, Val Loss: 0.5279, Val Acc: 68.57%
#
# [Epoch 191]
# Pred: MATTEO | True: MATTEO
# Pred: DESCLOUS | True: DESCLOUS
# Pred: BRANDILY | True: BRANDILY
# Train Loss: 0.1256, Train Acc: 81.20%, Val Loss: 0.5302, Val Acc: 66.97%
#
# [Epoch 192]
# Pred: MATHIS | True: MATHIS
# Pred: HUYNH-VAN | True: HUYNH-VAN
# Pred: LAURE | True: LAURE
# Train Loss: 0.1221, Train Acc: 81.70%, Val Loss: 0.5357, Val Acc: 68.27%
#
# [Epoch 193]
# Pred: GOURBAIN | True: GOURDAIN
# Pred: ANTOINE | True: ANTOINE
# Pred: COTTEREAU | True: COTTEREAU
# Train Loss: 0.1167, Train Acc: 82.02%, Val Loss: 0.5338, Val Acc: 66.77%
#
# [Epoch 194]
# Pred: SOPRANSI | True: SOPRANSI
# Pred: ALEXANDRE | True: ALEXANDRE
# Pred: LEPAIN | True: LEPAIN
# Train Loss: 0.1257, Train Acc: 81.76%, Val Loss: 0.5086, Val Acc: 67.87%
#
# [Epoch 195]
# Pred: HELVEZE | True: BELVEZE
# Pred: LOISEAU | True: LOISEAU
# Pred: VINON | True: NINON
# Train Loss: 0.1122, Train Acc: 82.62%, Val Loss: 0.5006, Val Acc: 67.97%
#
# [Epoch 196]
# Pred: ASSRAOUI | True: ASSRAOUI
# Pred: ROMANE | True: ROMANE
# Pred: FERCHECHE | True: FERCHECHE
# Train Loss: 0.1054, Train Acc: 83.38%, Val Loss: 0.5013, Val Acc: 68.57%
#
# [Epoch 197]
# Pred: GASQUET | True: GASQUET
# Pred: BAPTISTE | True: BAPTISTE
# Pred: MAVOUNIA-KOUKA | True: HAVOUNIA-KOUKA
# Train Loss: 0.1124, Train Acc: 82.48%, Val Loss: 0.5041, Val Acc: 67.27%
#
# [Epoch 198]
# Pred: ADJOUTE | True: ADJOUTE
# Pred: ALVES | True: ALVES
# Pred: YSEE | True: YSEE
# Train Loss: 0.1306, Train Acc: 79.94%, Val Loss: 0.5292, Val Acc: 67.97%
#
# [Epoch 199]
# Pred: JOAN | True: JOAN
# Pred: NONIR | True: NADIR
# Pred: CELENA | True: CELENA
# Train Loss: 0.1295, Train Acc: 81.58%, Val Loss: 0.5168, Val Acc: 67.47%
# Saving the last model with 67.47
#
# Final Test Accuracy: 0.651

# %%
def decode_prediction(output, idx2char, blank_idx=0):
    output = output.permute(1, 0, 2)
    pred_labels = torch.argmax(output, dim=2)

    pred_texts = []
    for seq in pred_labels:
        text = []
        prev = None
        for idx in seq:
            idx = idx.item()
            if idx != blank_idx and idx != prev:
                text.append(idx2char.get(idx, ''))
            prev = idx
        pred_texts.append(''.join(text))
    return pred_texts

# %%
import matplotlib.pyplot as plt 


plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(train_accuracy, label = 'Training Accuracy')
plt.plot(val_accuracy, label = 'Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(train_losses, label = 'Training Loss')
plt.plot(val_losses, label = 'Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.title('Training and Validation Loss')

model.eval()
with torch.no_grad():
    for i, (images, labels, _) in enumerate(test_loader):
        if i >= 2:
            break

        images = images.to(device)
        outputs = model(images)

        pred_texts = decode_prediction(outputs, idx2char, blank_idx=0)

        gt_texts = [label for label in labels] 

        fig, axes = plt.subplots(1, 5, figsize=(15, 3))
        for j in range(min(5, len(images))):
            ax = axes[j]
            img = images[j].cpu().numpy().squeeze()
            ax.imshow(img, cmap='gray')
            ax.set_title(f"GT: {gt_texts[j]}\nPred: {pred_texts[j]}")
            ax.axis('off')
        plt.show()
